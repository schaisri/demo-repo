# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
img=mpimg.imread('data/stinkbug.png')
print(img.shape)
# Out:
# (375, 500, 3)

# %%
imgplot = plt.imshow(img)

# %%
img
# Out:
# array([[[0.40784314, 0.40784314, 0.40784314],
#         [0.40784314, 0.40784314, 0.40784314],
#         [0.40784314, 0.40784314, 0.40784314],
#         ...,
#         [0.42745098, 0.42745098, 0.42745098],
#         [0.42745098, 0.42745098, 0.42745098],
#         [0.42745098, 0.42745098, 0.42745098]],
#
#        [[0.4117647 , 0.4117647 , 0.4117647 ],
#         [0.4117647 , 0.4117647 , 0.4117647 ],
#         [0.4117647 , 0.4117647 , 0.4117647 ],
#         ...,
#         [0.42745098, 0.42745098, 0.42745098],
#         [0.42745098, 0.42745098, 0.42745098],
#         [0.42745098, 0.42745098, 0.42745098]],
#
#        [[0.41960785, 0.41960785, 0.41960785],
#         [0.41568628, 0.41568628, 0.41568628],
#         [0.41568628, 0.41568628, 0.41568628],
#         ...,
#         [0.43137255, 0.43137255, 0.43137255],
#         [0.43137255, 0.43137255, 0.43137255],
#         [0.43137255, 0.43137255, 0.43137255]],
#
#        ...,
#
#        [[0.4392157 , 0.4392157 , 0.4392157 ],
# ...

# %%
lum_img = img[:,:,0]
plt.imshow(lum_img)

# %%
plt.imshow(lum_img, cmap="hot")

# %%
imgplot = plt.imshow(lum_img)
imgplot.set_cmap('nipy_spectral')

# %%
imgplot = plt.imshow(lum_img)
plt.colorbar()

# %%
from PIL import Image
img = Image.open('stinkbug.png')
img.thumbnail((64, 64), Image.ANTIALIAS) # resizes image in-place
imgplot = plt.imshow(img)

# %%
imgplot = plt.imshow(img, interpolation="nearest")

# %%
imgplot = plt.imshow(img, interpolation="bicubic")

# %% [markdown]
# images with a single colormap

# %%
def func3(x, y):
    return (1 - x / 2 + x**5 + y**3) * np.exp(-(x**2 + y**2))

# make these smaller to increase the resolution
dx, dy = 0.5, 0.5
x = np.arange(-3.0, 3.0, dx)
y = np.arange(-3.0, 3.0, dy)
X, Y = np.meshgrid(x, y)
#extent = np.min(x), np.max(x), np.min(y), np.max(y)
fig = plt.figure(frameon=False)
Z2 = func3(X, Y)
im2 = plt.imshow(Z2, cmap=plt.cm.viridis, alpha=.9, interpolation='bilinear',
                 extent=extent)
#im2 = plt.imshow(Z2, cmap=plt.cm.viridis, alpha=.9, interpolation='bilinear')

plt.show()

# %%
Z2.shape
# Out:
# (12, 12)

# %%
print(Z2)
# Out:
# [[-4.07401958e-06 -2.91616937e-05 -1.28838776e-04 -4.27208432e-04
#   -1.20309814e-03 -2.47787853e-03 -3.20865491e-03 -2.51992738e-03
#   -1.15769821e-03 -2.49171046e-04  1.13016470e-05  1.67733714e-05]
#  [-6.10184431e-05 -4.13774960e-04 -1.61318598e-03 -4.36821155e-03
#   -1.07413876e-02 -2.16589209e-02 -2.82328917e-02 -2.23166755e-02
#   -1.00312132e-02 -1.58323825e-03  5.78979076e-04  3.04770355e-04]
#  [-5.61691858e-04 -3.65618657e-03 -1.27475799e-02 -2.67247244e-02
#   -5.05346025e-02 -9.67293362e-02 -1.28209472e-01 -1.02969939e-01
#   -4.37966555e-02 -3.01633459e-04  8.05110307e-03  3.16118156e-03]
#  [-3.17215472e-03 -2.00988598e-02 -6.44289068e-02 -1.02411062e-01
#   -1.11475848e-01 -1.76995778e-01 -2.50323158e-01 -2.12907965e-01
#   -7.27016397e-02  4.96433283e-02  5.52592496e-02  1.91323851e-02]
#  [-1.09640830e-02 -6.84652497e-02 -2.08876357e-01 -2.65360985e-01
#   -6.76676416e-02  6.26729243e-02  0.00000000e+00 -6.26729243e-02
# ...

# %%
A = np.random.rand(5, 5)
print(A)
# Out:
# [[0.08844078 0.01209071 0.95053398 0.16159074 0.6841286 ]
#  [0.66391077 0.23296708 0.41736053 0.74754212 0.43852177]
#  [0.84433749 0.55899361 0.78174876 0.92365198 0.17351634]
#  [0.02981245 0.06723925 0.87018173 0.89582699 0.67582694]
#  [0.54510565 0.84916159 0.35850455 0.58476179 0.13178749]]

# %%
fig, ax1 = plt.subplots()
ax1.imshow(A, interpolation='bicubic')

# %%
N = 100
x = 0.9 * np.random.rand(N)
y = 0.9 * np.random.rand(N)
area = (20 * np.random.rand(N))**2  # 0 to 10 point radii
plt.scatter(x, y, s=area, marker='o', c=area)

# %%
tamp0=np.zeros((N,3))
tamp0[:,0]=x
tamp0[:,1]=y
tamp0[:,2]=area
tamp0
# Out:
# array([[8.19143406e-01, 2.20781432e-02, 1.01940439e+02],
#        [7.73872066e-01, 4.16806325e-01, 7.55346631e+01],
#        [8.40141042e-01, 1.02052227e-01, 6.53392236e+00],
#        [1.24435881e-01, 1.02435000e-01, 2.89401051e+02],
#        [4.45373560e-01, 3.60729777e-01, 1.18856911e+02],
#        [2.04601357e-01, 3.65075060e-01, 3.93795122e+01],
#        [1.97451462e-01, 6.99682635e-01, 8.77424069e+01],
#        [7.39653856e-01, 6.95841272e-01, 3.01688955e+01],
#        [3.00401860e-01, 7.18618057e-01, 3.97242177e+02],
#        [1.43323461e-01, 2.03704200e-01, 1.29518983e+02],
#        [4.99458114e-01, 5.82783814e-02, 2.12384986e+01],
#        [5.95265995e-01, 5.45788429e-02, 2.66870975e+02],
#        [5.34211418e-01, 5.33058295e-02, 4.50067078e+01],
#        [6.51155889e-01, 5.25469451e-01, 8.72726252e+01],
#        [7.31500278e-01, 7.22851968e-02, 3.30682335e+00],
#        [5.58087499e-01, 1.98330651e-01, 2.26356888e+02],
# ...

# %%
B = np.random.rand(5, 5)

fig, axs = plt.subplots(1, 3, figsize=(10, 3))
for ax, interp in zip(axs, ['nearest', 'bilinear', 'bicubic']):
    ax.imshow(B, interpolation=interp)
    ax.set_title(interp.capitalize())
    ax.grid(True)

plt.show()

# %%
print(B)
# Out:
# [[0.11745545 0.4292019  0.80404589 0.18115343 0.67351491]
#  [0.33421468 0.67303502 0.51584011 0.43427889 0.06076602]
#  [0.54455612 0.00295884 0.31030678 0.42910037 0.16751591]
#  [0.21855642 0.48110803 0.27190319 0.63679025 0.95611446]
#  [0.31526546 0.83192467 0.67648158 0.44467899 0.65097876]]

# %%
img=mpimg.imread('data/whale.jpg')
plt.imshow(img)
print(img.shape)
# Out:
# (558, 992, 3)

# %% [markdown]
# https://www.rapidtables.com/web/color/RGB_Color.html

# %%
from IPython.display import IFrame, YouTubeVideo, SVG, HTML

# %%
IFrame("https://htmlcolorcodes.com/", width=800, height=500)
# Out:
#         <iframe
#             width="800"
#             height="500"
#             src="https://htmlcolorcodes.com/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
img
# Out:
# array([[[  8, 107, 188],
#         [  9, 106, 187],
#         [  8, 105, 186],
#         ...,
#         [  7,  78, 160],
#         [  7,  78, 160],
#         [  7,  78, 160]],
#
#        [[  5, 102, 183],
#         [  4, 101, 182],
#         [  3, 100, 181],
#         ...,
#         [  4,  76, 158],
#         [  5,  77, 159],
#         [  5,  77, 159]],
#
#        [[  0,  94, 176],
#         [  0,  94, 176],
#         [  0,  93, 175],
#         ...,
#         [  1,  73, 155],
#         [  1,  73, 155],
#         [  1,  73, 155]],
#
#        ...,
#
#        [[  2,  49, 139],
#         [  2,  49, 139],
#         [  2,  49, 139],
#         ...,
#         [  0,  42, 126],
#         [  0,  42, 126],
#         [  0,  42, 126]],
#
#        [[  2,  49, 139],
#         [  2,  49, 139],
#         [  2,  49, 139],
#         ...,
#         [  0,  42, 126],
#         [  0,  42, 126],
#         [  0,  42, 126]],
#
#        [[  2,  49, 139],
#         [  2,  49, 139],
#         [  2,  49, 139],
# ...
